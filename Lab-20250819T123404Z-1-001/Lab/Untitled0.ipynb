# %%
import numpy as np
from collections import Counter
def euclidian_distance(x1, x2):
  return np.sqrt((x1-x2)**2)
# Out:
#   File "/tmp/ipython-input-1-477312459.py", line 4
#
#     ^
# SyntaxError: incomplete input
