# %% [markdown]
# # Neural Network with Keras for Kaggle's Titanic Dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pathData = "/content/drive/MyDrive/AI Research More/Deep Neural Network"

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# ignore Deprecation Warning
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning) 

# Random Forest Regressor
from sklearn.ensemble import RandomForestRegressor

# Neural Network
import keras 
from keras.models import Sequential 
from keras.layers import Dense

# load the data
df_train = pd.read_csv(pathData + '/train.csv')
df_test = pd.read_csv(pathData + '/test.csv')
df = df_train.append(df_test , ignore_index = True)

# some quick inspections
print(df_train.shape, df_test.shape, df_train.columns.values)
# Out:
# Using TensorFlow backend.
# ((891, 12), (418, 11), array(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'], dtype=object))
# /usr/local/lib/python2.7/dist-packages/pandas/core/frame.py:6692: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)

# %% [markdown]
# ## Data Preprocessing
# Let's look at individual features one by one. Missing values will have to be filled. Categorical features need to be transformed to numerical values.

# %% [markdown]
# ### Pclass

# %%
# check if there is any NAN
df['Pclass'].isnull().sum(axis=0)
# Out:
# 0

# %%
# inspect the correlation between Pclass and Survived
df[['Pclass', 'Survived']].groupby(['Pclass'], as_index=False).mean()
# Out:
#    Pclass  Survived
# 0       1  0.629630
# 1       2  0.472826
# 2       3  0.242363

# %% [markdown]
# We can see that a higher class (lower value) has a higher survival rate. This should be a very useful feature.

# %% [markdown]
# ### Name

# %%
df.Name.head(10)
# Out:
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# 5                                     Moran, Mr. James
# 6                              McCarthy, Mr. Timothy J
# 7                       Palsson, Master. Gosta Leonard
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                  Nasser, Mrs. Nicholas (Adele Achem)
# Name: Name, dtype: object

# %% [markdown]
# Each name has a title, which is clearly what matters since it contains information of gender or status. Let's extract the titles from these names.

# %%
df['Title'] = df.Name.map( lambda x: x.split(',')[1].split( '.' )[0].strip())

# inspect the amount of people for each title
df['Title'].value_counts()
# Out:
# Mr              757
# Miss            260
# Mrs             197
# Master           61
# Rev               8
# Dr                8
# Col               4
# Major             2
# Mlle              2
# Ms                2
# Mme               1
# the Countess      1
# Don               1
# Lady              1
# Sir               1
# Jonkheer          1
# Dona              1
# Capt              1
# Name: Title, dtype: int64

# %% [markdown]
# Looks like the main ones are "Master", "Miss", "Mr", "Mrs". Some of the others can be be merged into some of these four categories. For the rest, I'll just call them "Others"

# %%
df['Title'] = df['Title'].replace('Mlle', 'Miss')
df['Title'] = df['Title'].replace(['Mme','Lady','Ms'], 'Mrs')
df.Title.loc[ (df.Title !=  'Master') & (df.Title !=  'Mr') & (df.Title !=  'Miss') 
             & (df.Title !=  'Mrs')] = 'Others'

# inspect the correlation between Title and Survived
df[['Title', 'Survived']].groupby(['Title'], as_index=False).mean()
# Out:
# /usr/local/lib/python2.7/dist-packages/pandas/core/indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
#     Title  Survived
# 0  Master  0.575000
# 1    Miss  0.701087
# 2      Mr  0.156673
# 3     Mrs  0.796875
# 4  Others  0.318182

# %%
# inspect the amount of people for each title
df['Title'].value_counts()
# Out:
# Mr        757
# Miss      262
# Mrs       201
# Master     61
# Others     28
# Name: Title, dtype: int64

# %% [markdown]
# Now we can use dummy variables for these titles and drop the original names

# %%
df = pd.concat([df, pd.get_dummies(df['Title'])], axis=1).drop(labels=['Name'], axis=1)

# %% [markdown]
# ### Sex

# %%
# check if there is any NAN
df.Sex.isnull().sum(axis=0)
# Out:
# 0

# %%
# inspect the correlation between Sex and Survived
df[['Sex', 'Survived']].groupby(['Sex'], as_index=False).mean()
# Out:
#       Sex  Survived
# 0  female  0.742038
# 1    male  0.188908

# %%
# map the two genders to 0 and 1
df.Sex = df.Sex.map({'male':0, 'female':1})

# %% [markdown]
# ### Age

# %%
# check if there is any NAN
df.Age.isnull().sum(axis=0)
# Out:
# 263

# %% [markdown]
# There are 263 missing values! Age can probably be inferred from other features such as Title, Fare, SibSp, Parch. So I decide to come back to Age after I finish inspecting the other features.

# %% [markdown]
# ### SibSp and Parch

# %%
# check if there is any NAN
df.SibSp.isnull().sum(axis=0), df.Parch.isnull().sum(axis=0)
# Out:
# (0, 0)

# %%
# create a new feature "Family"
df['Family'] = df['SibSp'] + df['Parch'] + 1

# inspect the correlation between Family and Survived
df[['Family', 'Survived']].groupby(['Family'], as_index=False).mean()
# Out:
#    Family  Survived
# 0       1  0.303538
# 1       2  0.552795
# 2       3  0.578431
# 3       4  0.724138
# 4       5  0.200000
# 5       6  0.136364
# 6       7  0.333333
# 7       8  0.000000
# 8      11  0.000000

# %%
# inspect the amount of people for each Family size
df['Family'].value_counts()
# Out:
# 1     790
# 2     235
# 3     159
# 4      43
# 6      25
# 5      22
# 7      16
# 11     11
# 8       8
# Name: Family, dtype: int64

# %% [markdown]
# We can see that the survival rate increases with the family size, but not beyond Family = 4. Also, the amount of people in big families is much lower than those in small families. I will combine all the data with Family > 4 into one category. Since people in big families have an even lower survival rate (0.161290) than those who are alone, I decided to map data with Family > 4 to Family = 0, such that the survival rate always increases as Family increases.

# %%
df.Family = df.Family.map(lambda x: 0 if x > 4 else x)
df[['Family', 'Survived']].groupby(['Family'], as_index=False).mean()
# Out:
#    Family  Survived
# 0       0  0.161290
# 1       1  0.303538
# 2       2  0.552795
# 3       3  0.578431
# 4       4  0.724138

# %%
df['Family'].value_counts()
# Out:
# 1    790
# 2    235
# 3    159
# 0     82
# 4     43
# Name: Family, dtype: int64

# %% [markdown]
# ### Ticket

# %%
# check if there is any NAN
df.Ticket.isnull().sum(axis=0)
# Out:
# 0

# %%
df.Ticket.head(20)
# Out:
# 0            A/5 21171
# 1             PC 17599
# 2     STON/O2. 3101282
# 3               113803
# 4               373450
# 5               330877
# 6                17463
# 7               349909
# 8               347742
# 9               237736
# 10             PP 9549
# 11              113783
# 12           A/5. 2151
# 13              347082
# 14              350406
# 15              248706
# 16              382652
# 17              244373
# 18              345763
# 19                2649
# Name: Ticket, dtype: object

# %% [markdown]
# It looks like there are two types of tickets: (1) number (2) letters + number
#
# Ticket names with letters probably represent some special classes. For the numbers, the majority of tickets have their first digit = 1, 2, or 3, which probably also represent different classes. So I just keep the first element (a letter or a single-digit  number) of these ticket names

# %%
df.Ticket = df.Ticket.map(lambda x: x[0])

# inspect the correlation between Ticket and Survived
df[['Ticket', 'Survived']].groupby(['Ticket'], as_index=False).mean()
# Out:
#    Ticket  Survived
# 0       1  0.630137
# 1       2  0.464481
# 2       3  0.239203
# 3       4  0.200000
# 4       5  0.000000
# 5       6  0.166667
# 6       7  0.111111
# 7       8  0.000000
# 8       9  1.000000
# 9       A  0.068966
# 10      C  0.340426
# 11      F  0.571429
# 12      L  0.250000
# 13      P  0.646154
# 14      S  0.323077
# 15      W  0.153846

# %%
# inspect the amount of people for each type of tickets
df['Ticket'].value_counts()
# Out:
# 3    429
# 2    278
# 1    210
# S     98
# P     98
# C     77
# A     42
# W     19
# 7     13
# F     13
# 4     11
# 6      9
# L      5
# 5      3
# 9      2
# 8      2
# Name: Ticket, dtype: int64

# %% [markdown]
# We can see that the majority of tickets are indeed "3", "2", and "1", and their corresponding survival rates are "1" > "2" > "3". For the others, the survival rate is low except for "9","C","F","P", and "S". However, "9" and "F" are very small sample. The correlation we see here probably comes from Pclass or Fare, so let's check.

# %%
df[['Ticket', 'Fare']].groupby(['Ticket'], as_index=False).mean()
# Out:
#    Ticket        Fare
# 0       1   65.771211
# 1       2   20.235194
# 2       3   15.380682
# 3       4   16.764036
# 4       5   19.262500
# 5       6   19.153711
# 6       7    9.197438
# 7       8    8.397900
# 8       9    7.750000
# 9       A   10.189681
# 10      C   28.152273
# 11      F   24.677246
# 12      L    1.515000
# 13      P  119.698253
# 14      S   17.542900
# 15      W   31.056579

# %%
df[['Ticket', 'Pclass']].groupby(['Ticket'], as_index=False).mean()
# Out:
#    Ticket    Pclass
# 0       1  1.147619
# 1       2  2.309353
# 2       3  2.904429
# 3       4  3.000000
# 4       5  2.333333
# 5       6  2.111111
# 6       7  3.000000
# 7       8  3.000000
# 8       9  3.000000
# 9       A  3.000000
# 10      C  2.558442
# 11      F  1.846154
# 12      L  3.000000
# 13      P  1.102041
# 14      S  2.561224
# 15      W  2.315789

# %% [markdown]
# Indeed, there is some relation between Ticket and Fare, or between Ticket and Pclass. Also, one interesting thing is that "P" corresponds to very high Fare and Pcalss (better than "1"). This is an additional information that cannot be seen in other features. So keeping Ticket as a feature might be useful.
#
# I'll come back to Ticket later. I don't further transform it now because its current form might be useful for guessing some missing values in other features.

# %% [markdown]
# ### Fare

# %%
# check if there is any NAN
df.Fare.isnull().sum(axis=0)
# Out:
# 1

# %% [markdown]
# Only one missing value. Fare can probably be inferred from Ticket, Pclass, Cabin and Embarked. Let's see the corresponding values of for these features.

# %%
df.Ticket[df.Fare.isnull()]
# Out:
# 1043    3
# Name: Ticket, dtype: object

# %%
df.Pclass[df.Fare.isnull()]
# Out:
# 1043    3
# Name: Pclass, dtype: int64

# %%
df.Cabin[df.Fare.isnull()]
# Out:
# 1043    NaN
# Name: Cabin, dtype: object

# %%
df.Embarked[df.Fare.isnull()]
# Out:
# 1043    S
# Name: Embarked, dtype: object

# %% [markdown]
# There is no corresponding value for Cabin, so let's look at the relation between Fare and the three features.

# %%
# use boxplot to visualize the distribution of Fare for each Pclass
sns.boxplot('Pclass','Fare',data=df)
plt.ylim(0, 300) # ignore one data point with Fare > 500
plt.show()

# %%
# inspect the correlation between Pclass and Fare
df[['Pclass', 'Fare']].groupby(['Pclass']).mean()
# Out:
#              Fare
# Pclass
# 1       87.508992
# 2       21.179196
# 3       13.302889

# %%
# divide the standard deviation by the mean. A lower ratio means a tighter 
# distribution of Fare in each Pclass
df[['Pclass', 'Fare']].groupby(['Pclass']).std() / df[['Pclass', 'Fare']].groupby(['Pclass']).mean()
# Out:
#             Fare
# Pclass
# 1       0.919302
# 2       0.642476
# 3       0.864050

# %%
# use boxplot to visualize the distribution of Fare for each Ticket
sns.boxplot('Ticket','Fare',data=df)
plt.ylim(0, 300) # ignore one data point with Fare > 500
plt.show()

# %%
# inspect the correlation between Ticket and Fare 
# (we saw this earlier)
df[['Ticket', 'Fare']].groupby(['Ticket']).mean()
# Out:
#               Fare
# Ticket
# 1        65.771211
# 2        20.235194
# 3        15.380682
# 4        16.764036
# 5        19.262500
# 6        19.153711
# 7         9.197438
# 8         8.397900
# 9         7.750000
# A        10.189681
# C        28.152273
# F        24.677246
# L         1.515000
# P       119.698253
# S        17.542900
# W        31.056579

# %%
# divide the standard deviation by the mean. A lower ratio means a tighter 
# distribution of Fare in each Ticket type
df[['Ticket', 'Fare']].groupby(['Ticket']).std() /  df[['Ticket', 'Fare']].groupby(['Ticket']).mean()
# Out:
#             Fare
# Ticket
# 1       0.817411
# 2       1.284139
# 3       1.351244
# 4       0.497578
# 5       0.284367
# 6       0.735873
# 7       0.080078
# 8       0.005961
# 9       0.000000
# A       0.466846
# C       0.736299
# F       0.556023
# L       2.236068
# P       0.944596
# S       1.024639
# W       0.676999

# %%
# use boxplot to visualize the distribution of Fare for each Embarked
sns.boxplot('Embarked','Fare',data=df)
plt.ylim(0, 300) # ignore one data point with Fare > 500
plt.show()

# %%
# inspect the correlation between Embarked and Fare
df[['Embarked', 'Fare']].groupby(['Embarked']).mean()
# Out:
#                Fare
# Embarked
# C         62.336267
# Q         12.409012
# S         27.418824

# %%
# divide the standard deviation by the mean. A lower ratio means a tighter 
# distribution of Fare in each Embarked
df[['Embarked', 'Fare']].groupby(['Embarked']).std() /  df[['Embarked', 'Fare']].groupby(['Embarked']).mean()
# Out:
#               Fare
# Embarked
# C         1.350514
# Q         1.097278
# S         1.352954

# %% [markdown]
# Looks like Fare indeed has correlation with these three features. I'll guess the missing value using the median value of (Pcalss = 3) & (Ticket = 3) & (Embarked = S)

# %%
guess_Fare = df.Fare.loc[ (df.Ticket == '3') & (df.Pclass == 3) & (df.Embarked == 'S')].median()
df.Fare.fillna(guess_Fare , inplace=True)

# inspect the mean Fare values for people who died and survived
df[['Fare', 'Survived']].groupby(['Survived'],as_index=False).mean()
# Out:
#    Survived       Fare
# 0       0.0  22.117887
# 1       1.0  48.395408

# %%
# visualize the distribution of Fare for people who survived and died
grid = sns.FacetGrid(df, hue='Survived', size=4, aspect=1.5)
grid.map(plt.hist, 'Fare', alpha=.5, bins=range(0,210,10))
grid.add_legend()
plt.show()
# Out:
# /usr/local/lib/python2.7/dist-packages/seaborn/axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
# visualize the correlation between Fare and Survived using a scatter plot
df[['Fare', 'Survived']].groupby(['Fare'],as_index=False).mean().plot.scatter('Fare','Survived')
plt.show()

# %% [markdown]
# We can see that people with lower Fare are less likely to survive. But this is certainly not a smooth curve if we don't bin the data. It would be better to feed machine learning algorithms with intervals of Fare, because using the original Fare values would likely cause over-fitting.

# %%
# bin Fare into five intervals with equal amount of people
df['Fare-bin'] = pd.qcut(df.Fare,5,labels=[1,2,3,4,5]).astype(int)

# inspect the correlation between Fare-bin and Survived
df[['Fare-bin', 'Survived']].groupby(['Fare-bin'], as_index=False).mean()
# Out:
#    Fare-bin  Survived
# 0         1  0.217877
# 1         2  0.201087
# 2         3  0.426901
# 3         4  0.443243
# 4         5  0.645349

# %% [markdown]
# Now the correlation is clear after binning the data!
#
# ### Cabin

# %%
# check if there is any NAN
df.Cabin.isnull().sum(axis=0)
# Out:
# 1014

# %% [markdown]
# This is highly incomplete. We have two choices: (1) map the missing ones to a new cabin category "unknown" (2) just drop this feature. I have tried both and I decided to choose (2)

# %%
df = df.drop(labels=['Cabin'], axis=1)

# %% [markdown]
# ### Embarked

# %%
# check if there is any NAN
df.Embarked.isnull().sum(axis=0)
# Out:
# 2

# %%
df.describe(include=['O']) # S is the most common
# Out:
#        Embarked Ticket Title
# count      1307   1309  1309
# unique        3     16     5
# top           S      3    Mr
# freq        914    429   757

# %%
# fill the NAN
df.Embarked.fillna('S' , inplace=True )

# %%
# inspect the correlation between Embarked and Survived as well as some other features
df[['Embarked', 'Survived','Pclass','Fare', 'Age', 'Sex']].groupby(['Embarked'], as_index=False).mean()
# Out:
#   Embarked  Survived    Pclass       Fare        Age       Sex
# 0        C  0.553571  1.851852  62.336267  32.332170  0.418519
# 1        Q  0.389610  2.894309  12.409012  28.630000  0.487805
# 2        S  0.339009  2.344978  27.512485  29.298151  0.319869

# %% [markdown]
# The survival rate does change between different Embarked values. However, it is due to the changes of other features. For example, people from Embarked = C are more likely to survive because they are generally richer (Pclass, Fare). People from Embarked = S has the lowest survival rate because it has the lowest fraction of female passengers, even though they are a bit richer than people from Embarked = Q.
#
# I therefore decided to drop this feature as well.

# %%
df = df.drop(labels='Embarked', axis=1)

# %% [markdown]
# Now we can go back to **Age** and try to fill the missing values. Let's see how it relates to other features

# %%
# visualize the correlation between Title and Age
grid = sns.FacetGrid(df, col='Title', size=3, aspect=0.8, sharey=False)
grid.map(plt.hist, 'Age', alpha=.5, bins=range(0,105,5))
plt.show()

# %%
# inspect the mean Age for each Title
df[['Title', 'Age']].groupby(['Title']).mean()
# Out:
#               Age
# Title
# Master   5.482642
# Miss    21.795236
# Mr      32.252151
# Mrs     36.930636
# Others  45.074074

# %%
# inspect the standard deviation of Age for each Title
df[['Title', 'Age']].groupby(['Title']).std()
# Out:
#               Age
# Title
# Master   4.161554
# Miss    12.192794
# Mr      12.422089
# Mrs     12.872625
# Others  11.303253

# %%
# visualize the correlation between Fare-bin and Age
grid = sns.FacetGrid(df, col='Fare-bin', size=3, aspect=0.8, sharey=False)
grid.map(plt.hist, 'Age', alpha=.5, bins=range(0,105,5))
plt.show()

# %%
# inspect the mean Age for each Fare-bin
df[['Fare-bin', 'Age']].groupby(['Fare-bin']).mean()
# Out:
#                 Age
# Fare-bin
# 1         27.848315
# 2         27.898241
# 3         26.144009
# 4         30.728604
# 5         35.877913

# %%
# inspect the standard deviation of Age for each Fare-bin
df[['Fare-bin', 'Age']].groupby(['Fare-bin']).std()
# Out:
#                 Age
# Fare-bin
# 1         10.812580
# 2         10.995650
# 3         13.523208
# 4         17.466022
# 5         15.150724

# %%
# visualize the correlation between SibSp and Age
grid = sns.FacetGrid(df, col='SibSp', col_wrap=4, size=3.0, aspect=0.8, sharey=False)
grid.map(plt.hist, 'Age', alpha=.5, bins=range(0,105,5))
plt.show()

# %%
# inspect the mean Age for each SibSp
df[['SibSp', 'Age']].groupby(['SibSp']).mean()
# Out:
#              Age
# SibSp
# 0      30.921766
# 1      31.058071
# 2      23.569444
# 3      16.312500
# 4       8.772727
# 5      10.166667
# 8      14.500000

# %%
# inspect the standard deviation of Age for each SibSp
df[['SibSp', 'Age']].groupby(['SibSp']).std()
# Out:
#              Age
# SibSp
# 0      13.059751
# 1      15.974482
# 2      14.910640
# 3      11.824938
# 4       8.005545
# 5       5.192944
# 8            NaN

# %%
# visualize the correlation between Parch and Age
grid = sns.FacetGrid(df, col='Parch', col_wrap=4, size=3.0, aspect=0.8, sharey=False)
grid.map(plt.hist, 'Age', alpha=.5, bins=range(0,105,5))
plt.show()

# %%
# inspect the mean Age for each Parch
df[['Parch', 'Age']].groupby(['Parch']).mean()
# Out:
#              Age
# Parch
# 0      31.969401
# 1      24.965625
# 2      18.975979
# 3      38.875000
# 4      47.600000
# 5      39.333333
# 6      41.500000
# 9            NaN

# %%
# inspect the standard deviation of Age for each Parch
df[['Parch', 'Age']].groupby(['Parch']).std()
# Out:
#              Age
# Parch
# 0      12.422617
# 1      18.410885
# 2      14.564066
# 3      16.295815
# 4      14.432602
# 5       1.032796
# 6       2.121320
# 9            NaN

# %% [markdown]
# The change of Age as a function of Title, Fare-bin, or SibSp is quite significant, so I'll use them to guess the missing values. I use a random forest regressor to do this.

# %%
# notice that instead of using Title, we should use its corresponding dummy variables 
df_sub = df[['Age','Master','Miss','Mr','Mrs','Others','Fare-bin','SibSp']]

X_train  = df_sub.dropna().drop('Age', axis=1)
y_train  = df['Age'].dropna()
X_test = df_sub.loc[np.isnan(df.Age)].drop('Age', axis=1)

regressor = RandomForestRegressor(n_estimators = 300)
regressor.fit(X_train, y_train)
y_pred = np.round(regressor.predict(X_test),1)
df.Age.loc[df.Age.isnull()] = y_pred

df.Age.isnull().sum(axis=0) # no more NAN now
# Out:
# 0

# %% [markdown]
# And then we still need to bin the data into different Age intervals, for the same reason as Fare

# %%
bins = [ 0, 4, 12, 18, 30, 50, 65, 100] # This is somewhat arbitrary
age_index = (1,2,3,4,5,6,7) #('baby','child','teenager','young','mid-age','over-50','senior')
df['Age-bin'] = pd.cut(df.Age, bins, labels=age_index).astype(int)

df[['Age-bin', 'Survived']].groupby(['Age-bin'],as_index=False).mean()
# Out:
#    Age-bin  Survived
# 0        1  0.675000
# 1        2  0.452381
# 2        3  0.402597
# 3        4  0.315789
# 4        5  0.427083
# 5        6  0.375000
# 6        7  0.125000

# %% [markdown]
# Now we can look at **Ticket** again

# %%
df[['Ticket', 'Survived']].groupby(['Ticket'], as_index=False).mean()
# Out:
#    Ticket  Survived
# 0       1  0.630137
# 1       2  0.464481
# 2       3  0.239203
# 3       4  0.200000
# 4       5  0.000000
# 5       6  0.166667
# 6       7  0.111111
# 7       8  0.000000
# 8       9  1.000000
# 9       A  0.068966
# 10      C  0.340426
# 11      F  0.571429
# 12      L  0.250000
# 13      P  0.646154
# 14      S  0.323077
# 15      W  0.153846

# %%
df['Ticket'].value_counts()
# Out:
# 3    429
# 2    278
# 1    210
# S     98
# P     98
# C     77
# A     42
# W     19
# 7     13
# F     13
# 4     11
# 6      9
# L      5
# 5      3
# 9      2
# 8      2
# Name: Ticket, dtype: int64

# %% [markdown]
# The main categories of Ticket are "1", "2", "3", "P", "S", and "C", so I will combine all the others into "4"

# %%
df['Ticket'] = df['Ticket'].replace(['A','W','F','L','5','6','7','8','9'], '4')

# check the correlation again
df[['Ticket', 'Survived']].groupby(['Ticket'], as_index=False).mean()
# Out:
#   Ticket  Survived
# 0      1  0.630137
# 1      2  0.464481
# 2      3  0.239203
# 3      4  0.166667
# 4      C  0.340426
# 5      P  0.646154
# 6      S  0.323077

# %%
# dummy encoding
df = pd.get_dummies(df,columns=['Ticket'])

# %% [markdown]
# ## Modeling and Prediction
#
# Now we can drop the features we don't need and split the data into training and test sets. Then I will use Keras to build a neural network architecture.

# %%
df = df.drop(labels=['SibSp','Parch','Age','Fare','Title'], axis=1)
y_train = df[0:891]['Survived'].values
X_train = df[0:891].drop(['Survived','PassengerId'], axis=1).values
X_test  = df[891:].drop(['Survived','PassengerId'], axis=1).values

# %%
# Initialising the NN
model = Sequential()

# layers
model.add(Dense(9, kernel_initializer = 'uniform', activation = 'relu', input_dim = 17))
model.add(Dense(9, kernel_initializer = 'uniform', activation = 'relu'))
model.add(Dense(5, kernel_initializer = 'uniform', activation = 'relu'))
model.add(Dense(1, kernel_initializer = 'uniform', activation = 'sigmoid'))

# summary
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 9)                 162
# _________________________________________________________________
# dense_2 (Dense)              (None, 9)                 90
# _________________________________________________________________
# dense_3 (Dense)              (None, 5)                 50
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 6
# =================================================================
# Total params: 308
# Trainable params: 308
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compiling the NN
model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# Train the NN
model.fit(X_train, y_train, batch_size = 32, epochs = 200)
# Out:
# Epoch 1/200
# 891/891 [==============================] - 0s 497us/step - loss: 0.6916 - accuracy: 0.6150
# Epoch 2/200
# 891/891 [==============================] - 0s 42us/step - loss: 0.6887 - accuracy: 0.6162
# Epoch 3/200
# 891/891 [==============================] - 0s 40us/step - loss: 0.6845 - accuracy: 0.6162
# Epoch 4/200
# 891/891 [==============================] - 0s 39us/step - loss: 0.6763 - accuracy: 0.6162
# Epoch 5/200
# 891/891 [==============================] - 0s 47us/step - loss: 0.6599 - accuracy: 0.6162
# Epoch 6/200
# 891/891 [==============================] - 0s 42us/step - loss: 0.6324 - accuracy: 0.6162
# Epoch 7/200
# 891/891 [==============================] - 0s 55us/step - loss: 0.5985 - accuracy: 0.6162
# Epoch 8/200
# 891/891 [==============================] - 0s 41us/step - loss: 0.5674 - accuracy: 0.6162
# Epoch 9/200
# 891/891 [==============================] - 0s 40us/step - loss: 0.5450 - accuracy: 0.6162
# Epoch 10/200
# 891/891 [==============================] - 0s 45us/step - loss: 0.5319 - accuracy: 0.6162
# Epoch 11/200
# 891/891 [==============================] - 0s 41us/step - loss: 0.5250 - accuracy: 0.6162
# Epoch 12/200
# 891/891 [==============================] - 0s 41us/step - loss: 0.5180 - accuracy: 0.6162
# Epoch 13/200
# 891/891 [==============================] - 0s 43us/step - loss: 0.5137 - accuracy: 0.6162
# Epoch 14/200
# 891/891 [==============================] - 0s 42us/step - loss: 0.5100 - accuracy: 0.8092
# Epoch 15/200
# 891/891 [==============================] - 0s 41us/step - loss: 0.5066 - accuracy: 0.8238
# Epoch 16/200
# 891/891 [==============================] - 0s 42us/step - loss: 0.5027 - accuracy: 0.8204
# Epoch 17/200
# 891/891 [==============================] - 0s 42us/step - loss: 0.4982 - accuracy: 0.8227
# Epoch 18/200
# 891/891 [==============================] - 0s 39us/step - loss: 0.4959 - accuracy: 0.8238
# Epoch 19/200
# 891/891 [==============================] - 0s 40us/step - loss: 0.4923 - accuracy: 0.8249
# Epoch 20/200
# 891/891 [==============================] - 0s 44us/step - loss: 0.4894 - accuracy: 0.8238
# Epoch 21/200
# 891/891 [==============================] - 0s 41us/step - loss: 0.4878 - accuracy: 0.8272
# Epoch 22/200
# 891/891 [==============================] - 0s 39us/step - loss: 0.4859 - accuracy: 0.8272
# Epoch 23/200
# 891/891 [==============================] - 0s 44us/step - loss: 0.4829 - accuracy: 0.8193
# Epoch 24/200
# 891/891 [==============================] - 0s 39us/step - loss: 0.4804 - accuracy: 0.8260
# Epoch 25/200
# 891/891 [==============================] - 0s 43us/step - loss: 0.4779 - accuracy: 0.8316
# Epoch 26/200
# 891/891 [==============================] - 0s 44us/step - loss: 0.4753 - accuracy: 0.8350
# Epoch 27/200
# 891/891 [==============================] - 0s 44us/step - loss: 0.4752 - accuracy: 0.8395
# Epoch 28/200
# 891/891 [==============================] - 0s 38us/step - loss: 0.4722 - accuracy: 0.8316
# Epoch 29/200
# 891/891 [==============================] - 0s 44us/step - loss: 0.4693 - accuracy: 0.8328
# Epoch 30/200
# 891/891 [==============================] - 0s 46us/step - loss: 0.4669 - accuracy: 0.8316
# Epoch 31/200
# 891/891 [==============================] - 0s 42us/step - loss: 0.4649 - accuracy: 0.8373
# Epoch 32/200
# 891/891 [==============================] - 0s 51us/step - loss: 0.4641 - accuracy: 0.8395
# Epoch 33/200
# 891/891 [==============================] - 0s 42us/step - loss: 0.4622 - accuracy: 0.8339
# Epoch 34/200
# 891/891 [==============================] - 0s 42us/step - loss: 0.4605 - accuracy: 0.8316
# Epoch 35/200
# 891/891 [==============================] - 0s 41us/step - loss: 0.4593 - accuracy: 0.8373
# Epoch 36/200
# 891/891 [==============================] - 0s 43us/step - loss: 0.4572 - accuracy: 0.8283
# Epoch 37/200
# 891/891 [==============================] - 0s 39us/step - loss: 0.4555 - accuracy: 0.8350
# Epoch 38/200
# 891/891 [==============================] - 0s 46us/step - loss: 0.4544 - accuracy: 0.8339
# Epoch 39/200
# 891/891 [==============================] - 0s 38us/step - loss: 0.4533 - accuracy: 0.8350
# Epoch 40/200
# 891/891 [==============================] - 0s 46us/step - loss: 0.4515 - accuracy: 0.8350
# Epoch 41/200
# 891/891 [==============================] - 0s 38us/step - loss: 0.4502 - accuracy: 0.8373
# Epoch 42/200
# 891/891 [==============================] - 0s 46us/step - loss: 0.4498 - accuracy: 0.8283
# Epoch 43/200
# 891/891 [==============================] - 0s 47us/step - loss: 0.4480 - accuracy: 0.8305
# Epoch 44/200
# 891/891 [==============================] - 0s 40us/step - loss: 0.4467 - accuracy: 0.8328
# Epoch 45/200
# 891/891 [==============================] - 0s 41us/step - loss: 0.4469 - accuracy: 0.8260
# Epoch 46/200
# 891/891 [==============================] - 0s 41us/step - loss: 0.4450 - accuracy: 0.8294
# Epoch 47/200
# 891/891 [==============================] - 0s 40us/step - loss: 0.4430 - accuracy: 0.8305
# Epoch 48/200
# 891/891 [==============================] - 0s 40us/step - loss: 0.4434 - accuracy: 0.8339
# Epoch 49/200
# 891/891 [==============================] - 0s 39us/step - loss: 0.4432 - accuracy: 0.8272
# Epoch 50/200
# 891/891 [==============================] - 0s 41us/step - loss: 0.4415 - accuracy: 0.8294
# Epoch 51/200
# 891/891 [==============================] - 0s 40us/step - loss: 0.4408 - accuracy: 0.8316
# Epoch 52/200
# 891/891 [==============================] - 0s 40us/step - loss: 0.4402 - accuracy: 0.8316
# Epoch 53/200
# 891/891 [==============================] - 0s 45us/step - loss: 0.4401 - accuracy: 0.8328
# Epoch 54/200
# 891/891 [==============================] - 0s 58us/step - loss: 0.4381 - accuracy: 0.8294
# Epoch 55/200
# 891/891 [==============================] - 0s 41us/step - loss: 0.4379 - accuracy: 0.8305
# Epoch 56/200
# 891/891 [==============================] - 0s 43us/step - loss: 0.4403 - accuracy: 0.8305
# Epoch 57/200
# 891/891 [==============================] - 0s 40us/step - loss: 0.4351 - accuracy: 0.8305
# Epoch 58/200
# 891/891 [==============================] - 0s 39us/step - loss: 0.4375 - accuracy: 0.8272
# Epoch 59/200
# 891/891 [==============================] - 0s 40us/step - loss: 0.4357 - accuracy: 0.8316
# Epoch 60/200
# 891/891 [==============================] - 0s 46us/step - loss: 0.4337 - accuracy: 0.8305
# Epoch 61/200
# 891/891 [==============================] - 0s 40us/step - loss: 0.4358 - accuracy: 0.8316
# Epoch 62/200
# 891/891 [==============================] - 0s 39us/step - loss: 0.4333 - accuracy: 0.8294
# Epoch 63/200
# 891/891 [==============================] - 0s 42us/step - loss: 0.4340 - accuracy: 0.8316
# Epoch 64/200
# 891/891 [==============================] - 0s 41us/step - loss: 0.4316 - accuracy: 0.8305
# Epoch 65/200
# 891/891 [==============================] - 0s 37us/step - loss: 0.4328 - accuracy: 0.8361
# Epoch 66/200
# 891/891 [==============================] - 0s 45us/step - loss: 0.4340 - accuracy: 0.8294
# Epoch 67/200
# 891/891 [==============================] - 0s 43us/step - loss: 0.4311 - accuracy: 0.8283
# Epoch 68/200
# 891/891 [==============================] - 0s 43us/step - loss: 0.4300 - accuracy: 0.8305
# Epoch 69/200
# 891/891 [==============================] - 0s 48us/step - loss: 0.4294 - accuracy: 0.8305
# Epoch 70/200
# 891/891 [==============================] - 0s 46us/step - loss: 0.4307 - accuracy: 0.8294
# Epoch 71/200
# 891/891 [==============================] - 0s 43us/step - loss: 0.4287 - accuracy: 0.8283
# Epoch 72/200
# 891/891 [==============================] - 0s 46us/step - loss: 0.4289 - accuracy: 0.8294
# Epoch 73/200
# 891/891 [==============================] - 0s 40us/step - loss: 0.4271 - accuracy: 0.8339
# Epoch 74/200
# 891/891 [==============================] - 0s 42us/step - loss: 0.4269 - accuracy: 0.8305
# Epoch 75/200
# 891/891 [==============================] - 0s 49us/step - loss: 0.4259 - accuracy: 0.8316
# Epoch 76/200
# 891/891 [==============================] - 0s 42us/step - loss: 0.4285 - accuracy: 0.8305
# Epoch 77/200
# 891/891 [==============================] - 0s 42us/step - loss: 0.4251 - accuracy: 0.8305
# Epoch 78/200
# 891/891 [==============================] - 0s 48us/step - loss: 0.4265 - accuracy: 0.8294
# Epoch 79/200
# 891/891 [==============================] - 0s 46us/step - loss: 0.4263 - accuracy: 0.8294
# Epoch 80/200
# 891/891 [==============================] - 0s 38us/step - loss: 0.4288 - accuracy: 0.8350
# Epoch 81/200
# 891/891 [==============================] - 0s 40us/step - loss: 0.4271 - accuracy: 0.8283
# Epoch 82/200
# 891/891 [==============================] - 0s 41us/step - loss: 0.4239 - accuracy: 0.8305
# Epoch 83/200
# 891/891 [==============================] - 0s 45us/step - loss: 0.4244 - accuracy: 0.8283
# Epoch 84/200
# 891/891 [==============================] - 0s 40us/step - loss: 0.4243 - accuracy: 0.8260
# Epoch 85/200
# 891/891 [==============================] - 0s 45us/step - loss: 0.4234 - accuracy: 0.8316
# Epoch 86/200
# 891/891 [==============================] - 0s 56us/step - loss: 0.4224 - accuracy: 0.8305
# Epoch 87/200
# 891/891 [==============================] - 0s 43us/step - loss: 0.4231 - accuracy: 0.8294
# Epoch 88/200
# 891/891 [==============================] - 0s 40us/step - loss: 0.4208 - accuracy: 0.8316
# Epoch 89/200
# 891/891 [==============================] - 0s 40us/step - loss: 0.4210 - accuracy: 0.8283
# Epoch 90/200
# 891/891 [==============================] - 0s 47us/step - loss: 0.4211 - accuracy: 0.8316
# Epoch 91/200
# 891/891 [==============================] - 0s 40us/step - loss: 0.4217 - accuracy: 0.8272
# Epoch 92/200
# 891/891 [==============================] - 0s 41us/step - loss: 0.4203 - accuracy: 0.8283
# Epoch 93/200
# 891/891 [==============================] - 0s 42us/step - loss: 0.4201 - accuracy: 0.8305
# Epoch 94/200
# 891/891 [==============================] - 0s 43us/step - loss: 0.4194 - accuracy: 0.8305
# Epoch 95/200
# 891/891 [==============================] - 0s 42us/step - loss: 0.4205 - accuracy: 0.8328
# Epoch 96/200
# 891/891 [==============================] - 0s 43us/step - loss: 0.4191 - accuracy: 0.8294
# Epoch 97/200
# 891/891 [==============================] - 0s 41us/step - loss: 0.4189 - accuracy: 0.8305
# Epoch 98/200
# 891/891 [==============================] - 0s 48us/step - loss: 0.4176 - accuracy: 0.8305
# Epoch 99/200
# 891/891 [==============================] - 0s 41us/step - loss: 0.4176 - accuracy: 0.8294
# Epoch 100/200
# 891/891 [==============================] - 0s 41us/step - loss: 0.4181 - accuracy: 0.8350
# Epoch 101/200
# 891/891 [==============================] - 0s 40us/step - loss: 0.4174 - accuracy: 0.8339
# Epoch 102/200
# 891/891 [==============================] - 0s 45us/step - loss: 0.4167 - accuracy: 0.8283
# Epoch 103/200
# 891/891 [==============================] - 0s 48us/step - loss: 0.4169 - accuracy: 0.8328
# Epoch 104/200
# 891/891 [==============================] - 0s 42us/step - loss: 0.4182 - accuracy: 0.8283
# Epoch 105/200
# 891/891 [==============================] - 0s 41us/step - loss: 0.4167 - accuracy: 0.8272
# Epoch 106/200
# 891/891 [==============================] - 0s 48us/step - loss: 0.4160 - accuracy: 0.8316
# Epoch 107/200
# 891/891 [==============================] - 0s 43us/step - loss: 0.4195 - accuracy: 0.8260
# Epoch 108/200
# 891/891 [==============================] - 0s 41us/step - loss: 0.4160 - accuracy: 0.8316
# Epoch 109/200
# 891/891 [==============================] - 0s 39us/step - loss: 0.4188 - accuracy: 0.8316
# Epoch 110/200
# 891/891 [==============================] - 0s 47us/step - loss: 0.4153 - accuracy: 0.8294
# Epoch 111/200
# 891/891 [==============================] - 0s 42us/step - loss: 0.4149 - accuracy: 0.8339
# Epoch 112/200
# 891/891 [==============================] - 0s 41us/step - loss: 0.4163 - accuracy: 0.8294
# Epoch 113/200
# 891/891 [==============================] - 0s 42us/step - loss: 0.4147 - accuracy: 0.8339
# Epoch 114/200
# 891/891 [==============================] - 0s 42us/step - loss: 0.4153 - accuracy: 0.8339
# Epoch 115/200
# 891/891 [==============================] - 0s 39us/step - loss: 0.4153 - accuracy: 0.8339
# Epoch 116/200
# 891/891 [==============================] - 0s 43us/step - loss: 0.4138 - accuracy: 0.8316
# Epoch 117/200
# 891/891 [==============================] - 0s 50us/step - loss: 0.4131 - accuracy: 0.8316
# Epoch 118/200
# 891/891 [==============================] - 0s 41us/step - loss: 0.4132 - accuracy: 0.8316
# Epoch 119/200
# 891/891 [==============================] - 0s 44us/step - loss: 0.4156 - accuracy: 0.8260
# Epoch 120/200
# 891/891 [==============================] - 0s 45us/step - loss: 0.4125 - accuracy: 0.8316
# Epoch 121/200
# 891/891 [==============================] - 0s 40us/step - loss: 0.4129 - accuracy: 0.8316
# Epoch 122/200
# 891/891 [==============================] - 0s 42us/step - loss: 0.4138 - accuracy: 0.8305
# Epoch 123/200
# 891/891 [==============================] - 0s 47us/step - loss: 0.4133 - accuracy: 0.8283
# Epoch 124/200
# 891/891 [==============================] - 0s 41us/step - loss: 0.4133 - accuracy: 0.8294
# Epoch 125/200
# 891/891 [==============================] - 0s 39us/step - loss: 0.4132 - accuracy: 0.8305
# Epoch 126/200
# 891/891 [==============================] - 0s 57us/step - loss: 0.4124 - accuracy: 0.8339
# Epoch 127/200
# 891/891 [==============================] - 0s 43us/step - loss: 0.4121 - accuracy: 0.8227
# Epoch 128/200
# 891/891 [==============================] - 0s 39us/step - loss: 0.4143 - accuracy: 0.8316
# Epoch 129/200
# 891/891 [==============================] - 0s 46us/step - loss: 0.4117 - accuracy: 0.8283
# Epoch 130/200
# 891/891 [==============================] - 0s 40us/step - loss: 0.4116 - accuracy: 0.8305
# Epoch 131/200
# 891/891 [==============================] - 0s 39us/step - loss: 0.4115 - accuracy: 0.8305
# Epoch 132/200
# 891/891 [==============================] - 0s 40us/step - loss: 0.4117 - accuracy: 0.8294
# Epoch 133/200
# 891/891 [==============================] - 0s 41us/step - loss: 0.4133 - accuracy: 0.8283
# Epoch 134/200
# 891/891 [==============================] - 0s 45us/step - loss: 0.4128 - accuracy: 0.8328
# Epoch 135/200
# 891/891 [==============================] - 0s 44us/step - loss: 0.4110 - accuracy: 0.8272
# Epoch 136/200
# 891/891 [==============================] - 0s 45us/step - loss: 0.4115 - accuracy: 0.8283
# Epoch 137/200
# 891/891 [==============================] - 0s 46us/step - loss: 0.4109 - accuracy: 0.8249
# Epoch 138/200
# 891/891 [==============================] - 0s 40us/step - loss: 0.4112 - accuracy: 0.8350
# Epoch 139/200
# 891/891 [==============================] - 0s 41us/step - loss: 0.4120 - accuracy: 0.8227
# Epoch 140/200
# 891/891 [==============================] - 0s 41us/step - loss: 0.4107 - accuracy: 0.8316
# Epoch 141/200
# 891/891 [==============================] - 0s 43us/step - loss: 0.4118 - accuracy: 0.8328
# Epoch 142/200
# 891/891 [==============================] - 0s 45us/step - loss: 0.4118 - accuracy: 0.8316
# Epoch 143/200
# 891/891 [==============================] - 0s 46us/step - loss: 0.4110 - accuracy: 0.8328
# Epoch 144/200
# 891/891 [==============================] - 0s 45us/step - loss: 0.4103 - accuracy: 0.8272
# Epoch 145/200
# 891/891 [==============================] - 0s 46us/step - loss: 0.4109 - accuracy: 0.8328
# Epoch 146/200
# 891/891 [==============================] - 0s 45us/step - loss: 0.4097 - accuracy: 0.8328
# Epoch 147/200
# 891/891 [==============================] - 0s 47us/step - loss: 0.4132 - accuracy: 0.8215
# Epoch 148/200
# 891/891 [==============================] - 0s 51us/step - loss: 0.4119 - accuracy: 0.8272
# Epoch 149/200
# 891/891 [==============================] - 0s 51us/step - loss: 0.4099 - accuracy: 0.8305
# Epoch 150/200
# 891/891 [==============================] - 0s 53us/step - loss: 0.4102 - accuracy: 0.8294
# Epoch 151/200
# 891/891 [==============================] - 0s 41us/step - loss: 0.4091 - accuracy: 0.8316
# Epoch 152/200
# 891/891 [==============================] - 0s 44us/step - loss: 0.4091 - accuracy: 0.8339
# Epoch 153/200
# 891/891 [==============================] - 0s 41us/step - loss: 0.4089 - accuracy: 0.8328
# Epoch 154/200
# 891/891 [==============================] - 0s 42us/step - loss: 0.4102 - accuracy: 0.8350
# Epoch 155/200
# 891/891 [==============================] - 0s 52us/step - loss: 0.4109 - accuracy: 0.8339
# Epoch 156/200
# 891/891 [==============================] - 0s 43us/step - loss: 0.4086 - accuracy: 0.8328
# Epoch 157/200
# 891/891 [==============================] - 0s 45us/step - loss: 0.4092 - accuracy: 0.8339
# Epoch 158/200
# 891/891 [==============================] - 0s 44us/step - loss: 0.4120 - accuracy: 0.8283
# Epoch 159/200
# 891/891 [==============================] - 0s 46us/step - loss: 0.4084 - accuracy: 0.8339
# Epoch 160/200
# 891/891 [==============================] - 0s 40us/step - loss: 0.4089 - accuracy: 0.8350
# Epoch 161/200
# 891/891 [==============================] - 0s 48us/step - loss: 0.4114 - accuracy: 0.8294
# Epoch 162/200
# 891/891 [==============================] - 0s 42us/step - loss: 0.4077 - accuracy: 0.8294
# Epoch 163/200
# 891/891 [==============================] - 0s 44us/step - loss: 0.4100 - accuracy: 0.8283
# Epoch 164/200
# 891/891 [==============================] - 0s 48us/step - loss: 0.4086 - accuracy: 0.8361
# Epoch 165/200
# 891/891 [==============================] - 0s 46us/step - loss: 0.4089 - accuracy: 0.8305
# Epoch 166/200
# 891/891 [==============================] - 0s 44us/step - loss: 0.4080 - accuracy: 0.8305
# Epoch 167/200
# 891/891 [==============================] - 0s 43us/step - loss: 0.4094 - accuracy: 0.8294
# Epoch 168/200
# 891/891 [==============================] - 0s 48us/step - loss: 0.4092 - accuracy: 0.8316
# Epoch 169/200
# 891/891 [==============================] - 0s 41us/step - loss: 0.4086 - accuracy: 0.8305
# Epoch 170/200
# 891/891 [==============================] - 0s 43us/step - loss: 0.4074 - accuracy: 0.8350
# Epoch 171/200
# 891/891 [==============================] - 0s 46us/step - loss: 0.4096 - accuracy: 0.8294
# Epoch 172/200
# 891/891 [==============================] - 0s 43us/step - loss: 0.4088 - accuracy: 0.8305
# Epoch 173/200
# 891/891 [==============================] - 0s 42us/step - loss: 0.4084 - accuracy: 0.8260
# Epoch 174/200
# 891/891 [==============================] - 0s 49us/step - loss: 0.4075 - accuracy: 0.8283
# Epoch 175/200
# 891/891 [==============================] - 0s 41us/step - loss: 0.4080 - accuracy: 0.8339
# Epoch 176/200
# 891/891 [==============================] - 0s 41us/step - loss: 0.4079 - accuracy: 0.8316
# Epoch 177/200
# 891/891 [==============================] - 0s 40us/step - loss: 0.4075 - accuracy: 0.8294
# Epoch 178/200
# 891/891 [==============================] - 0s 52us/step - loss: 0.4079 - accuracy: 0.8316
# Epoch 179/200
# 891/891 [==============================] - 0s 41us/step - loss: 0.4071 - accuracy: 0.8339
# Epoch 180/200
# 891/891 [==============================] - 0s 41us/step - loss: 0.4097 - accuracy: 0.8272
# Epoch 181/200
# 891/891 [==============================] - 0s 40us/step - loss: 0.4085 - accuracy: 0.8294
# Epoch 182/200
# 891/891 [==============================] - 0s 40us/step - loss: 0.4088 - accuracy: 0.8316
# Epoch 183/200
# 891/891 [==============================] - 0s 41us/step - loss: 0.4069 - accuracy: 0.8316
# Epoch 184/200
# 891/891 [==============================] - 0s 48us/step - loss: 0.4119 - accuracy: 0.8238
# Epoch 185/200
# 891/891 [==============================] - 0s 47us/step - loss: 0.4077 - accuracy: 0.8305
# Epoch 186/200
# 891/891 [==============================] - 0s 43us/step - loss: 0.4075 - accuracy: 0.8260
# Epoch 187/200
# 891/891 [==============================] - 0s 42us/step - loss: 0.4088 - accuracy: 0.8305
# Epoch 188/200
# 891/891 [==============================] - 0s 43us/step - loss: 0.4066 - accuracy: 0.8305
# Epoch 189/200
# 891/891 [==============================] - 0s 44us/step - loss: 0.4069 - accuracy: 0.8305
# Epoch 190/200
# 891/891 [==============================] - 0s 50us/step - loss: 0.4065 - accuracy: 0.8283
# Epoch 191/200
# 891/891 [==============================] - 0s 45us/step - loss: 0.4067 - accuracy: 0.8305
# Epoch 192/200
# 891/891 [==============================] - 0s 45us/step - loss: 0.4090 - accuracy: 0.8260
# Epoch 193/200
# 891/891 [==============================] - 0s 42us/step - loss: 0.4077 - accuracy: 0.8283
# Epoch 194/200
# 891/891 [==============================] - 0s 39us/step - loss: 0.4069 - accuracy: 0.8316
# Epoch 195/200
# 891/891 [==============================] - 0s 43us/step - loss: 0.4081 - accuracy: 0.8283
# Epoch 196/200
# 891/891 [==============================] - 0s 49us/step - loss: 0.4056 - accuracy: 0.8316
# Epoch 197/200
# 891/891 [==============================] - 0s 43us/step - loss: 0.4075 - accuracy: 0.8328
# Epoch 198/200
# 891/891 [==============================] - 0s 48us/step - loss: 0.4068 - accuracy: 0.8294
# Epoch 199/200
# 891/891 [==============================] - 0s 44us/step - loss: 0.4070 - accuracy: 0.8272
# Epoch 200/200
# 891/891 [==============================] - 0s 44us/step - loss: 0.4075 - accuracy: 0.8294

# %% [markdown]
# We can now produce the prediction.

# %%
y_pred = model.predict(X_train)
y_final = (y_pred > 0.5).astype(int).reshape(X_train.shape[0])

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

actual = y_train
predicted = y_final
# confusion matrix
matrix = confusion_matrix(actual,predicted, labels=[1,0])
print('Confusion matrix : \n',matrix)

# outcome values order in sklearn
tp, fn, fp, tn = confusion_matrix(actual,predicted,labels=[1,0]).reshape(-1)
print('Outcome values : \n', tp, fn, fp, tn)

# classification report for precision, recall f1-score and accuracy
matrix = classification_report(actual,predicted,labels=[1,0])
# Out:
# ('Confusion matrix : \n', array([[248,  94],
#        [ 55, 494]]))
# ('Outcome values : \n', 248, 94, 55, 494)

# %%
print(matrix)
# Out:
#               precision    recall  f1-score   support
#
#            1       0.82      0.73      0.77       342
#            0       0.84      0.90      0.87       549
#
#    micro avg       0.83      0.83      0.83       891
#    macro avg       0.83      0.81      0.82       891
# weighted avg       0.83      0.83      0.83       891
